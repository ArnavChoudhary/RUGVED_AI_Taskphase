# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data =pd.read_csv("bollywood.csv")
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
data.shape
# Out:
# (149, 10)

# %%
data["Genre"].str.strip().value_counts().sort_values(ascending= False)
# Out:
# Comedy      36
# Drama       35
# Thriller    29
# Romance     25
# Action      24
# Name: Genre, dtype: int64

# %%
data["Genre"].str.strip().value_counts().sort_values(ascending= True)
# Out:
# Action      24
# Romance     25
# Thriller    29
# Drama       35
# Comedy      36
# Name: Genre, dtype: int64

# %%
data["Genre"].str.strip().value_counts().idxmax()
# Out:
# 'Comedy'

# %%
data["Genre"].str.strip().value_counts().sort_values(ascending= True).idxmin()
# Out:
# 'Action'

# %%
data["Genre"].str.strip().value_counts().sort_values(ascending= True).nlargest(1)
# Out:
# Comedy    36
# Name: Genre, dtype: int64

# %%
pd.crosstab(data.Genre,data.ReleaseTime)
# Out:
# ReleaseTime  FS  HS  LW   N
# Genre
#  Drama        4   6   1  24
# Action        3   3   3  12
# Action        0   0   0   3
# Comedy        3   5   5  23
# Romance       3   3   4  15
# Thriller      4   1   1  20
# Thriller      0   0   1   2

# %%
data["Release Date"].dtype
# Out:
# dtype('O')

# %% [markdown]
# frame["Month"]=frame.Release Date.str.extract.(r'\b')

# %%
data["Release Date"]=pd.to_datetime(data["Release Date"])
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
data["month"]=data["Release Date"].dt.month
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
# Out:
# 1     False
# 3     False
# 5     False
# 2     False
# 7     False
# 4     False
# 6     False
# 9     False
# 11    False
# 10    False
# 8     False
# 12    False
# Name: month, dtype: bool

# %%
data[data.Budget>=25].month.value_counts()
# Out:
# 2     9
# 1     8
# 3     7
# 8     7
# 7     6
# 11    6
# 6     5
# 9     5
# 4     4
# 10    4
# 5     3
# 12    2
# Name: month, dtype: int64

# %%
data["ROI"] = (data.BoxOfficeCollection - data.Budget) / data.Budget
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
data.corr()
# Out:
#                          SlNo    Budget  BoxOfficeCollection  YoutubeViews  \
# SlNo                 1.000000  0.116899             0.036908      0.025027
# Budget               0.116899  1.000000             0.650401      0.589038
# BoxOfficeCollection  0.036908  0.650401             1.000000      0.588632
# YoutubeViews         0.025027  0.589038             0.588632      1.000000
# YoutubeLikes         0.018163  0.608916             0.682517      0.884055
# YoutubeDislikes      0.035949  0.665343             0.623941      0.846739
# month                0.219954  0.258457             0.280943      0.289593
# ROI                  0.037314  0.072050             0.585042      0.252847
#
#                      YoutubeLikes  YoutubeDislikes     month       ROI
# SlNo                     0.018163         0.035949  0.219954  0.037314
# Budget                   0.608916         0.665343  0.258457  0.072050
# BoxOfficeCollection      0.682517         0.623941  0.280943  0.585042
# ...

# %%
sns.boxplot(data=data,y='Genre',x='YoutubeLikes')
# Out:
# <AxesSubplot:xlabel='YoutubeLikes', ylabel='Genre'>

# %%
sns.pairplot(data)

# %%
feature_corre = ['Budget','BoxOfficeCollection','YoutubeViews','YoutubeLikes','YoutubeDislikes']
sns.heatmap(data[feature_corre].corr(),annot=True);
